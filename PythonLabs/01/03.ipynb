# %%
# Медведев Георгий; лаб.1, упр.3

import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, (np.log((x*x + 1)*np.exp((-1)*np.abs(x)/10))/np.log(1 + np.tan(1/(1 + np.sin(x)*np.sin(x))))))
plt.grid(True)
plt.show()
