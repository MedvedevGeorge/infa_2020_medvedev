# %%
# Медведев Георгий; лаб.1, упр.2

import numpy as np
import plotly.express as px
x = np.arange(-3, 4.01, 0.005)
px.scatter(x=x, y=(x*x - x - 6)).show() # из графика (если приблизить) легко увидеть корни x == -2 и x == 3
# Out:
# <div>                            <div id="a3ad883c-a885-4b36-a8fa-51ac8ba65263" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3ad883c-a885-4b36-a8fa-51ac8ba65263")) {                    Plotly.newPlot(                        "a3ad883c-a885-4b36-a8fa-51ac8ba65263",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [-3.0, -2.995, -2.99, -2.9850000000000003, -2.9800000000000004, -2.9750000000000005, -2.9700000000000006, -2.9650000000000007, -2.960000000000001, -2.955000000000001, -2.950000000000001, -2.945000000000001, -2.9400000000000013, -2.9350000000000014, -2.9300000000000
# ...
